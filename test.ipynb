# %%
import asyncio

import pandas as pd

from config import KEY_JSON, SHEET_INFO, TRIGGERS, PROXIES, OPENAI
from core.planner import GoogleSheetPlanner

OPENAI_API_KEY = 'sk-REDACTED'
import os
import asyncio
import httpx
from openai import OpenAI
from openai import AsyncOpenAI

# %%
from core.reminder import TelegramNotifier

t = TelegramNotifier()

a = t.log('sdf')

# %%
await t.send_message(-4609043701,'test')
# Out:
# Message(channel_chat_created=False, chat=Chat(api_kwargs={'all_members_are_administrators': True}, id=-4609043701, title='TNT Aleksandr', type=<ChatType.GROUP>), date=datetime.datetime(2024, 12, 5, 9, 53, 45, tzinfo=<UTC>), delete_chat_photo=False, from_user=User(first_name='Ð“Ð°Ð»Ñ', id=6637868001, is_bot=True, username='galya_sponsor_bot'), group_chat_created=False, message_id=4445, supergroup_chat_created=False, text='test')

# %%
txt = 'asdasd'
TelegramNotifier().log(txt)

# %%
from index import handler

# %%
await handler('',1)

# %%
mode = 'test'

proxies = dict(PROXIES)


client = AsyncOpenAI(
    api_key=OPENAI,
    http_client=httpx.AsyncClient(proxies=proxies)
)

planner = GoogleSheetPlanner(KEY_JSON, SHEET_INFO, mode=mode)

model = 'gpt-3.5-turbo'
model = 'gpt-4o'
#model = 'gpt-4o-realtime-preview'
#model = 'o1-preview'

messages = 'ÐŸÑ€Ð¸Ð²ÐµÑ‚, ÐšÐ°Ðº Ð´ÐµÐ»Ð°?'
msgs = [{'role': 'user', 'content': messages}]
#ai = planner.openai_agent.chat(['ÐŸÑ€Ð¸Ð²ÐµÑ‚', 'ÐšÐ°Ðº Ð´ÐµÐ»Ð°?','Ð¢Ñ‹ ÐºÐ°ÐºÐ°Ñ Ð²ÐµÑ€ÑÑÐ¸ Ð“ÐŸÐ¢?'])
ai = planner.openai_agent.chat(msgs, model=model)
await ai
# Out:
# {'https://': 'http://proxy.example:8000'}
# [{'role': 'user', 'content': 'ÐŸÑ€Ð¸Ð²ÐµÑ‚, ÐšÐ°Ðº Ð´ÐµÐ»Ð°?'}]
# Error code: 404 - {'error': {'message': 'The model `o1-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}

# %%
client = AsyncOpenAI(
            api_key=planner.openai_agent.api_key,
            http_client=httpx.AsyncClient(proxies=planner.openai_agent.proxies),
        )

model = 'gpt-4o'

messages = 'ÐŸÑ€Ð¸Ð²ÐµÑ‚, ÐšÐ°Ðº Ð´ÐµÐ»Ð°?'

messages = [{'role': 'user', 'content': messages}]

completion = await client.chat.completions.create(
                model=model,
                messages=messages,
            )
completion.choices[0].message.content
# Out:
# 'ÐŸÑ€Ð¸Ð²ÐµÑ‚! Ð£ Ð¼ÐµÐ½Ñ Ð²ÑÑ‘ Ñ…Ð¾Ñ€Ð¾ÑˆÐ¾, ÑÐ¿Ð°ÑÐ¸Ð±Ð¾. ÐšÐ°Ðº Ñƒ Ñ‚ÐµÐ±Ñ Ð´ÐµÐ»Ð°?'

# %%
mdls = await client.models.list()

# %%
mm = []
for m in mdls:
    mm.append(m)

# %%
#mode = 'timer'
mode = 'test'
#mode = 'morning'
planner = GoogleSheetPlanner(KEY_JSON, SHEET_INFO, mode=mode)

# %%
if mode in {'timer', 'test'}:
    start_time = pd.Timestamp.now()
    planner.update()
    planner.task_to_calendar()  # Ð“ÐµÐ½ÐµÑ€Ð°Ñ†Ð¸Ñ Ð¸ Ð·Ð°Ð¿Ð¸ÑÑŒ ÐºÐ°Ð»ÐµÐ½Ð´Ð°Ñ€Ñ Ð·Ð°Ð´Ð°Ñ‡
    planner.designer_task_to_calendar()  # Ð“ÐµÐ½ÐµÑ€Ð°Ñ†Ð¸Ñ Ð¸ Ð·Ð°Ð¿Ð¸ÑÑŒ ÐºÐ°Ð»ÐµÐ½Ð´Ð°Ñ€Ñ Ð´Ð¸Ð·Ð°Ð¹Ð½ÐµÑ€Ð¾Ð²
    planner.task_to_table()  # Ð—Ð°Ð¿Ð¸ÑÑŒ Ð·Ð°Ð´Ð°Ñ‡ Ð² Ð»Ð¸ÑÑ‚ "Ð”Ð¸Ð·Ð°Ð¹Ð½ÐµÑ€Ñ‹"
    run_time = pd.Timestamp.now() - start_time
    print(f'Ð’Ñ€ÐµÐ¼Ñ Ð¾Ð±Ð½Ð¾Ð²Ð»ÐµÐ½Ð¸Ñ Ñ‚Ð°Ð±Ð»Ð¸Ñ†: {run_time}')
# Out:
# Getting sheet id for Ð¡Ð¿Ð¾Ð½ÑÐ¾Ñ€ÑÐºÐ¸Ðµ Ð¢ÐÐ¢ Ð—Ð°Ð´Ð°Ñ‡Ð¸
# Getting sheet id for Ð¡Ð¿Ð¾Ð½ÑÐ¾Ñ€ÑÐºÐ¸Ðµ Ð¢ÐÐ¢ ÐšÐ°Ð»ÐµÐ½Ð´Ð°Ñ€ÑŒ
# Getting sheet id for Ð¡Ð¿Ð¾Ð½ÑÐ¾Ñ€ÑÐºÐ¸Ðµ Ð¢ÐÐ¢ Ð”Ð¸Ð·Ð°Ð¹Ð½ÐµÑ€Ñ‹
# Ð’Ñ€ÐµÐ¼Ñ Ð¾Ð±Ð½Ð¾Ð²Ð»ÐµÐ½Ð¸Ñ Ñ‚Ð°Ð±Ð»Ð¸Ñ†: 0 days 00:00:25.885825

# %%
await planner.reminder.get_reminders()

# %%
await planner.reminder.send_reminders(mode=mode)

# %%
for designer_name, message in planner.reminder.enhanced_messages.items():
    designer = planner.reminder.people_manager.get_person(designer_name)
    if designer:
        vacation = designer.vacation != 'Ð´Ð°'
        test_chat_id = 91864013
        test = mode == 'test'
        chat_id = test_chat_id if test else designer.chat_id
        print(f'{mode=} {designer_name=} {chat_id=} {message=}')
        if chat_id and planner.reminder.tg_bot and vacation:
            await planner.reminder.tg_bot.send_message(chat_id, message)

# %%
#await planner.reminder.tg_bot.bot.send_message(chat_id=chat_id, text=message, parse_mode='Markdown')
await planner.reminder.tg_bot.bot.send_message(chat_id=chat_id, text=message)
# Out:
°Ð¿Ð¾Ð¼Ð½Ð¸Ñ‚ÑŒ Ð¿Ñ€Ð¾ Ð·Ð°Ð´Ð°Ñ‡ÐºÑƒ Ð½Ð° Ð¿ÑÑ‚Ð½Ð¸Ñ†Ñƒ, 15 Ð½Ð¾ÑÐ±Ñ€Ñ:\n1. ÐÑƒÐ¶Ð½Ð¾ ÑÐ´Ð°Ñ‚ÑŒ Ñ€Ð°ÑÐºÐ°Ð´Ñ€Ð¾Ð²ÐºÑƒ Ð´Ð»Ñ Ð³Ñ€Ð°Ñ„Ð¸Ñ‡ÐµÑÐºÐ¾Ð³Ð¾ Ñ€Ð¾Ð»Ð¸ÐºÐ° Ð¿Ð¾ Ð¿Ñ€Ð¾ÐµÐºÑ‚Ñƒ Â«Ð¡Ð±ÐµÑ€_ÐšÑ€ÐµÐ´Ð¸Ñ‚Ð½Ñ‹Ð¹ Ð¿Ð¾Ñ‚ÐµÐ½Ñ†Ð¸Ð°Ð»Â» Ð² Ñ€Ð°Ð¼ÐºÐ°Ñ… Â«Ð¨ÐžÐ Ð¢Ð¡Â».\n\nÐ•ÑÐ»Ð¸ Ñ‡Ñ‚Ð¾-Ñ‚Ð¾ Ð±ÑƒÐ´ÐµÑ‚ Ð½ÐµÑÑÐ½Ð¾ Ð¸Ð»Ð¸ Ð½ÑƒÐ¶Ð½Ñ‹ Ð´Ð¾Ð¿Ð¾Ð»Ð½Ð¸Ñ‚ÐµÐ»ÑŒÐ½Ñ‹Ðµ Ð¼Ð°Ñ‚ÐµÑ€Ð¸Ð°Ð»Ñ‹, Ð´Ð°Ð¹ Ð¼Ð½Ðµ Ð·Ð½Ð°Ñ‚ÑŒ. Ð”ÐµÑ€Ð¶Ð¸ÑÑŒ Ð¸ Ð¿Ð¾Ñ‡Ñ‚Ð¸ Ð²Ñ‹Ñ…Ð¾Ð´Ð½Ñ‹Ðµ! ðŸŒŸâ˜•\n'

# %%
from telegram.helpers import escape_markdown
import re
mmm = message[201:]

def selective_escape_markdown_v2(text):
    escaped_text = []
    # Ð¤Ð»Ð°Ð³Ð¸ Ð´Ð»Ñ Ð¾Ñ‚ÑÐ»ÐµÐ¶Ð¸Ð²Ð°Ð½Ð¸Ñ Ð¾Ñ‚ÐºÑ€Ñ‹Ñ‚Ñ‹Ñ… Ñ‚ÐµÐ³Ð¾Ð² Markdown
    in_bold = in_italic = in_code = in_pre = False

    i = 0
    while i < len(text):
        char = text[i]

        # ÐŸÑ€Ð¾Ð²ÐµÑ€ÑÐµÐ¼ Markdown-Ñ‚ÐµÐ³Ð¸ Ð¸ ÑƒÑÑ‚Ð°Ð½Ð°Ð²Ð»Ð¸Ð²Ð°ÐµÐ¼ Ñ„Ð»Ð°Ð³Ð¸, ÐµÑÐ»Ð¸ Ñ‚ÐµÐ³ Ð¾Ñ‚ÐºÑ€Ñ‹Ñ‚
        if char == '*' and not in_bold and (i + 1 < len(text) and text[i + 1] == '*'):
            in_bold = True
            escaped_text.append("**")
            i += 1
        elif char == '*' and in_bold and (i + 1 < len(text) and text[i + 1] == '*'):
            in_bold = False
            escaped_text.append("**")
            i += 1
        elif char == '_' and not in_italic:
            in_italic = True
            escaped_text.append("_")
        elif char == '_' and in_italic:
            in_italic = False
            escaped_text.append("_")
        elif char == '`' and not in_code:
            in_code = True
            escaped_text.append("`")
        elif char == '`' and in_code:
            in_code = False
            escaped_text.append("`")
        elif char == '~' and not in_pre and (i + 1 < len(text) and text[i + 1] == '~'):
            in_pre = True
            escaped_text.append("~~")
            i += 1
        elif char == '~' and in_pre and (i + 1 < len(text) and text[i + 1] == '~'):
            in_pre = False
            escaped_text.append("~~")
            i += 1
        # Ð­ÐºÑ€Ð°Ð½Ð¸Ñ€ÑƒÐµÐ¼ Ð²ÑÐµ Ð´Ñ€ÑƒÐ³Ð¸Ðµ ÑÐ¿ÐµÑ†Ð¸Ð°Ð»ÑŒÐ½Ñ‹Ðµ ÑÐ¸Ð¼Ð²Ð¾Ð»Ñ‹ Ð²Ð½Ðµ Markdown-Ñ€Ð°Ð·Ð¼ÐµÑ‚ÐºÐ¸
        elif char in "_*[]()~`>#+-=|{}.!" and not (in_bold or in_italic or in_code or in_pre):
            escaped_text.append(f"\\{char}")
        else:
            escaped_text.append(char)
        
        i += 1

    return ''.join(escaped_text)

mmm = 'asdfa *sdfa* sdf'

#mmm = selective_escape_markdown_v2(mmmm)# + '_'
print(mmm)
await planner.reminder.tg_bot.bot.send_message(chat_id=chat_id, text=mmm, parse_mode=ParseMode.MARKDOWN_V2,)
# Out:
# asdfa *sdfa* sdf
# Message(channel_chat_created=False, chat=Chat(first_name='YrSolo Ð®Ñ€Ð° Ð¡Ð¾Ð»Ð¾Ð²ÑŒÐµÐ²', id=91864013, type=<ChatType.PRIVATE>, username='yrsolo'), date=datetime.datetime(2024, 11, 14, 11, 3, 12, tzinfo=<UTC>), delete_chat_photo=False, entities=(MessageEntity(length=4, offset=6, type=<MessageEntityType.BOLD>),), from_user=User(first_name='Ð“Ð°Ð»Ñ', id=6637868001, is_bot=True, username='galya_sponsor_bot'), group_chat_created=False, message_id=4220, supergroup_chat_created=False, text='asdfa sdfa sdf')

# %%
try:
    # ÐŸÑ‹Ñ‚Ð°ÐµÐ¼ÑÑ Ð¾Ñ‚Ð¿Ñ€Ð°Ð²Ð¸Ñ‚ÑŒ ÑÐ¾Ð¾Ð±Ñ‰ÐµÐ½Ð¸Ðµ Ñ Ñ€Ð°Ð·Ð¼ÐµÑ‚ÐºÐ¾Ð¹ Markdown V2
    await planner.reminder.tg_bot.bot.send_message(chat_id=chat_id, text=message, parse_mode=ParseMode.MARKDOWN)
    print("Ð¡Ð¾Ð¾Ð±Ñ‰ÐµÐ½Ð¸Ðµ Ð¾Ñ‚Ð¿Ñ€Ð°Ð²Ð»ÐµÐ½Ð¾ ÑƒÑÐ¿ÐµÑˆÐ½Ð¾ Ñ Markdown.")
except Exception as e:
    print(f"ÐžÑˆÐ¸Ð±ÐºÐ° Ð¿Ñ€Ð¸ Ð¾Ñ‚Ð¿Ñ€Ð°Ð²ÐºÐµ Ñ Markdown: {e}")
    
    # Ð•ÑÐ»Ð¸ Ð¿Ñ€Ð¾Ð¸Ð·Ð¾ÑˆÐ»Ð° Ð¾ÑˆÐ¸Ð±ÐºÐ°, Ð¿Ð¾Ð²Ñ‚Ð¾Ñ€Ð½Ð¾ Ð¾Ñ‚Ð¿Ñ€Ð°Ð²Ð»ÑÐµÐ¼ ÑÐ¾Ð¾Ð±Ñ‰ÐµÐ½Ð¸Ðµ Ð±ÐµÐ· Ñ€Ð°Ð·Ð¼ÐµÑ‚ÐºÐ¸
    try:
        await planner.reminder.tg_bot.bot.send_message(chat_id=chat_id, text=message)
        print("Ð¡Ð¾Ð¾Ð±Ñ‰ÐµÐ½Ð¸Ðµ Ð¾Ñ‚Ð¿Ñ€Ð°Ð²Ð»ÐµÐ½Ð¾ ÑƒÑÐ¿ÐµÑˆÐ½Ð¾ Ð±ÐµÐ· Ñ€Ð°Ð·Ð¼ÐµÑ‚ÐºÐ¸.")
    except Exception as e:
        print(f"ÐžÑˆÐ¸Ð±ÐºÐ° Ð¿Ñ€Ð¸ Ð¾Ñ‚Ð¿Ñ€Ð°Ð²ÐºÐµ ÑÐ¾Ð¾Ð±Ñ‰ÐµÐ½Ð¸Ñ Ð±ÐµÐ· Ñ€Ð°Ð·Ð¼ÐµÑ‚ÐºÐ¸: {e}")
# Out:
# ÐžÑˆÐ¸Ð±ÐºÐ° Ð¿Ñ€Ð¸ Ð¾Ñ‚Ð¿Ñ€Ð°Ð²ÐºÐµ Ñ Markdown: Can't parse entities: can't find end of the entity starting at byte offset 358
# Ð¡Ð¾Ð¾Ð±Ñ‰ÐµÐ½Ð¸Ðµ Ð¾Ñ‚Ð¿Ñ€Ð°Ð²Ð»ÐµÐ½Ð¾ ÑƒÑÐ¿ÐµÑˆÐ½Ð¾ Ð±ÐµÐ· Ñ€Ð°Ð·Ð¼ÐµÑ‚ÐºÐ¸.

# %%
from telegram.constants import ParseMode

ParseMode.MARKDOWN_V2

# %%
await planner.reminder.tg_bot.send_message(chat_id, message)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 await planner.reminder.tg_bot.send_message(chat_id, message)
#
# File D:\PROJECTS\python\SCRIPT\TABLE_PARSE\core\reminder.py:37, in TelegramNotifier.send_message(self, chat_id, text)
#      30 async def send_message(self, chat_id, text):
#      31     """ÐžÑ‚Ð¿Ñ€Ð°Ð²Ð¸Ñ‚ÑŒ ÑÐ¾Ð¾Ð±Ñ‰ÐµÐ½Ð¸Ðµ Ð² Telegram.
#      32
#      33     Args:
#      34         chat_id (str): ID Ñ‡Ð°Ñ‚Ð°.
#      35         text (str): Ð¢ÐµÐºÑÑ‚ ÑÐ¾Ð¾Ð±Ñ‰ÐµÐ½Ð¸Ñ.
#      36     """
# ---> 37     return await self.bot.send_message(chat_id=chat_id, text=text, parse_mode='Markdown')
#
# File D:\PROJECTS\python\SCRIPT\TABLE_PARSE\venv\Lib\site-packages\telegram\ext\_extbot.py:2631, in ExtBot.send_message(self, chat_id, text, parse_mode, entities, disable_web_page_preview, disable_notification, protect_content, reply_to_message_id, allow_sending_without_reply, reply_markup, message_thread_id, read_timeout, write_timeout, connect_timeout, pool_timeout, api_kwargs, rate_limit_args)
#    2610 async def send_message(
#    2611     self,
#    2612     chat_id: Union[int, str],
#    (...)
#    2629     rate_limit_args: Optional[RLARGS] = None,
#    2630 ) -> Message:
# -> 2631     return await super().send_message(
#    2632         chat_id=chat_id,
#    2633         text=text,
#    2634         parse_mode=parse_mode,
#    2635         entities=entities,
#    2636         disable_web_page_preview=disable_web_page_preview,
#    2637         disable_notification=disable_notification,
#    2638         protect_content=protect_content,
#    2639         message_thread_id=message_thread_id,
#    2640         reply_to_message_id=reply_to_message_id,
#    2641         allow_sending_without_reply=allow_sending_without_reply,
#    2642         reply_markup=reply_markup,
#    2643         read_timeout=read_timeout,
#    2644         write_timeout=write_timeout,
#    2645         connect_timeout=connect_timeout,
#    2646         pool_timeout=pool_timeout,
#    2647         api_kwargs=self._merge_api_rl_kwargs(api_kwargs, rate_limit_args),
#    2648     )
#
# File D:\PROJECTS\python\SCRIPT\TABLE_PARSE\venv\Lib\site-packages\telegram\_bot.py:519, in Bot._log.<locals>.decorator(self, *args, **kwargs)
#     515 @functools.wraps(func)
#     516 async def decorator(self: "Bot", *args: Any, **kwargs: Any) -> Any:
#     517     # pylint: disable=protected-access
#     518     self._LOGGER.debug("Entering: %s", func.__name__)
# --> 519     result = await func(self, *args, **kwargs)  # skipcq: PYL-E1102
#     520     self._LOGGER.debug(result)
#     521     self._LOGGER.debug("Exiting: %s", func.__name__)
#
# File D:\PROJECTS\python\SCRIPT\TABLE_PARSE\venv\Lib\site-packages\telegram\_bot.py:840, in Bot.send_message(self, chat_id, text, parse_mode, entities, disable_web_page_preview, disable_notification, protect_content, reply_to_message_id, allow_sending_without_reply, reply_markup, message_thread_id, read_timeout, write_timeout, connect_timeout, pool_timeout, api_kwargs)
#     801 """Use this method to send text messages.
#     802
#     803 Args:
#    (...)
#     836
#     837 """
#     838 data: JSONDict = {"chat_id": chat_id, "text": text, "entities": entities}
# --> 840 return await self._send_message(
#     841     "sendMessage",
#     842     data,
#     843     reply_to_message_id=reply_to_message_id,
#     844     disable_notification=disable_notification,
#     845     reply_markup=reply_markup,
#     846     allow_sending_without_reply=allow_sending_without_reply,
#     847     protect_content=protect_content,
#     848     message_thread_id=message_thread_id,
#     849     parse_mode=parse_mode,
#     850     disable_web_page_preview=disable_web_page_preview,
#     851     read_timeout=read_timeout,
#     852     write_timeout=write_timeout,
#     853     connect_timeout=connect_timeout,
#     854     pool_timeout=pool_timeout,
#     855     api_kwargs=api_kwargs,
#     856 )
#
# File D:\PROJECTS\python\SCRIPT\TABLE_PARSE\venv\Lib\site-packages\telegram\ext\_extbot.py:529, in ExtBot._send_message(self, endpoint, data, reply_to_message_id, disable_notification, reply_markup, allow_sending_without_reply, protect_content, message_thread_id, caption, parse_mode, caption_entities, disable_web_page_preview, read_timeout, write_timeout, connect_timeout, pool_timeout, api_kwargs)
#     506 async def _send_message(
#     507     self,
#     508     endpoint: str,
#    (...)
#     527     # We override this method to call self._replace_keyboard and self._insert_callback_data.
#     528     # This covers most methods that have a reply_markup
# --> 529     result = await super()._send_message(
#     530         endpoint=endpoint,
#     531         data=data,
#     532         reply_to_message_id=reply_to_message_id,
#     533         disable_notification=disable_notification,
#     534         reply_markup=self._replace_keyboard(reply_markup),
#     535         allow_sending_without_reply=allow_sending_without_reply,
#     536         protect_content=protect_content,
#     537         message_thread_id=message_thread_id,
#     538         caption=caption,
#     539         parse_mode=parse_mode,
#     540         caption_entities=caption_entities,
#     541         disable_web_page_preview=disable_web_page_preview,
#     542         read_timeout=read_timeout,
#     543         write_timeout=write_timeout,
#     544         connect_timeout=connect_timeout,
#     545         pool_timeout=pool_timeout,
#     546         api_kwargs=api_kwargs,
#     547     )
#     548     if isinstance(result, Message):
#     549         self._insert_callback_data(result)
#
# File D:\PROJECTS\python\SCRIPT\TABLE_PARSE\venv\Lib\site-packages\telegram\_bot.py:697, in Bot._send_message(self, endpoint, data, reply_to_message_id, disable_notification, reply_markup, allow_sending_without_reply, protect_content, message_thread_id, caption, parse_mode, caption_entities, disable_web_page_preview, read_timeout, write_timeout, connect_timeout, pool_timeout, api_kwargs)
#     694 if caption_entities is not None:
#     695     data["caption_entities"] = caption_entities
# --> 697 result = await self._post(
#     698     endpoint,
#     699     data,
#     700     read_timeout=read_timeout,
#     701     write_timeout=write_timeout,
#     702     connect_timeout=connect_timeout,
#     703     pool_timeout=pool_timeout,
#     704     api_kwargs=api_kwargs,
#     705 )
#     707 if result is True:
#     708     return result
#
# File D:\PROJECTS\python\SCRIPT\TABLE_PARSE\venv\Lib\site-packages\telegram\_bot.py:607, in Bot._post(self, endpoint, data, read_timeout, write_timeout, connect_timeout, pool_timeout, api_kwargs)
#     604 # Drop any None values because Telegram doesn't handle them well
#     605 data = {key: value for key, value in data.items() if value is not None}
# --> 607 return await self._do_post(
#     608     endpoint=endpoint,
#     609     data=data,
#     610     read_timeout=read_timeout,
#     611     write_timeout=write_timeout,
#     612     connect_timeout=connect_timeout,
#     613     pool_timeout=pool_timeout,
#     614 )
#
# File D:\PROJECTS\python\SCRIPT\TABLE_PARSE\venv\Lib\site-packages\telegram\ext\_extbot.py:347, in ExtBot._do_post(self, endpoint, data, read_timeout, write_timeout, connect_timeout, pool_timeout)
#     345 # getting updates should not be rate limited!
#     346 if endpoint == "getUpdates" or not self.rate_limiter:
# --> 347     return await super()._do_post(
#     348         endpoint=endpoint,
#     349         data=data,
#     350         write_timeout=write_timeout,
#     351         connect_timeout=connect_timeout,
#     352         pool_timeout=pool_timeout,
#     353         read_timeout=read_timeout,
#     354     )
#     356 kwargs = {
#     357     "read_timeout": read_timeout,
#     358     "write_timeout": write_timeout,
#     359     "connect_timeout": connect_timeout,
#     360     "pool_timeout": pool_timeout,
#     361 }
#     362 self._LOGGER.debug(
#     363     "Passing request through rate limiter of type %s with rate_limit_args %s",
#     364     type(self.rate_limiter),
#     365     rate_limit_args,
#     366 )
#
# File D:\PROJECTS\python\SCRIPT\TABLE_PARSE\venv\Lib\site-packages\telegram\_bot.py:635, in Bot._do_post(self, endpoint, data, read_timeout, write_timeout, connect_timeout, pool_timeout)
#     629 request_data = RequestData(
#     630     parameters=[RequestParameter.from_input(key, value) for key, value in data.items()],
#     631 )
#     633 request = self._request[0] if endpoint == "getUpdates" else self._request[1]
# --> 635 return await request.post(
#     636     url=f"{self._base_url}/{endpoint}",
#     637     request_data=request_data,
#     638     read_timeout=read_timeout,
#     639     write_timeout=write_timeout,
#     640     connect_timeout=connect_timeout,
#     641     pool_timeout=pool_timeout,
#     642 )
#
# File D:\PROJECTS\python\SCRIPT\TABLE_PARSE\venv\Lib\site-packages\telegram\request\_baserequest.py:168, in BaseRequest.post(self, url, request_data, read_timeout, write_timeout, connect_timeout, pool_timeout)
#     127 @final
#     128 async def post(
#     129     self,
#    (...)
#     135     pool_timeout: ODVInput[float] = DEFAULT_NONE,
#     136 ) -> Union[JSONDict, List[JSONDict], bool]:
#     137     """Makes a request to the Bot API handles the return code and parses the answer.
#     138
#     139     Warning:
#    (...)
#     166
#     167     """
# --> 168     result = await self._request_wrapper(
#     169         url=url,
#     170         method="POST",
#     171         request_data=request_data,
#     172         read_timeout=read_timeout,
#     173         write_timeout=write_timeout,
#     174         connect_timeout=connect_timeout,
#     175         pool_timeout=pool_timeout,
#     176     )
#     177     json_data = self.parse_json_payload(result)
#     178     # For successful requests, the results are in the 'result' entry
#     179     # see https://core.telegram.org/bots/api#making-requests
#
# File D:\PROJECTS\python\SCRIPT\TABLE_PARSE\venv\Lib\site-packages\telegram\request\_baserequest.py:325, in BaseRequest._request_wrapper(self, url, method, request_data, read_timeout, write_timeout, connect_timeout, pool_timeout)
#     323     raise InvalidToken(message)
#     324 if code == HTTPStatus.BAD_REQUEST:  # 400
# --> 325     raise BadRequest(message)
#     326 if code == HTTPStatus.CONFLICT:  # 409
#     327     raise Conflict(message)
#
# BadRequest: Can't parse entities: can't find end of the entity starting at byte offset 358

# %%
if mode in {'morning', 'test'}:
    start_time = pd.Timestamp.now()
    now = pd.Timestamp.now(tz='Europe/Moscow')
    dow = now.dayofweek
    if dow in {0, 1, 2, 3, 4} or mode == 'test':
        await planner.send_reminders()
    run_time = pd.Timestamp.now() - start_time
    print(f'Ð’Ñ€ÐµÐ¼Ñ Ð¾Ñ‚Ð¿Ñ€Ð°Ð²ÐºÐ¸ Ð¾Ð¿Ð¾Ð²ÐµÑ‰ÐµÐ½Ð¸Ð¹: {run_time}')
# Out:
# {'https://': 'http://proxy.example:8000'}
# [{'role': 'system', 'content': "\nÐ˜Ð¼Ñ: Ð“Ð°Ð»Ñ\nÐ’Ð¾Ð·Ñ€Ð°ÑÑ‚: 28 Ð»ÐµÑ‚.\nÐ¥Ð°Ñ€Ð°ÐºÑ‚ÐµÑ€: Ð—Ð°Ð±Ð¾Ñ‚Ð»Ð¸Ð²Ñ‹Ð¹ Ð¸ Ð´Ð¾Ð±Ñ€Ð¾Ð¶ÐµÐ»Ð°Ñ‚ÐµÐ»ÑŒÐ½
°Ñ„Ð¸Ñ‡ÐµÑÐºÐ¸Ð¹ Ñ€Ð¾Ð»Ð¸Ðº // Ð´Ð»Ñ Ð¿Ñ€Ð¾ÐµÐºÑ‚Ð° Â«Ð¯Ñ€Ñ‡Ðµ Ð·Ð²ÐµÐ·Ð´Â» - Ð½ÑƒÐ¶Ð½Ð¾ Ð·Ð°Ð²ÐµÑ€ÑˆÐ¸Ñ‚ÑŒ Ð¸ ÑÐ´Ð°Ñ‚ÑŒ Ð°Ð½Ð¸Ð¼Ð°Ñ‚Ð¸Ðº.\n\nÐ•ÑÐ»Ð¸ Ð²Ð¾Ð·Ð½Ð¸ÐºÐ½ÑƒÑ‚ Ð²Ð¾Ð¿Ñ€Ð¾ÑÑ‹ Ð¸Ð»Ð¸ Ñ‚Ñ€ÑƒÐ´Ð½Ð¾ÑÑ‚Ð¸, Ð¾Ð±ÑÐ·Ð°Ñ‚ÐµÐ»ÑŒÐ½Ð¾ Ð´Ð°Ð¹ Ð·Ð½Ð°Ñ‚ÑŒ. Ð¯ Ð²ÑÐµÐ³Ð´Ð° Ñ€ÑÐ´Ð¾Ð¼ Ð¸ Ð³Ð¾Ñ‚Ð¾Ð²Ð° Ð¿Ð¾Ð¼Ð¾Ñ‡ÑŒ! ðŸŒŸ Ð£Ð´Ð°Ñ‡Ð½Ð¾Ð³Ð¾ Ð¸ Ð¿Ñ€Ð¾Ð´ÑƒÐºÑ‚Ð¸Ð²Ð½Ð¾Ð³Ð¾ Ð´Ð½Ñ!'
# Ð’Ñ€ÐµÐ¼Ñ Ð¾Ñ‚Ð¿Ñ€Ð°Ð²ÐºÐ¸ Ð¾Ð¿Ð¾Ð²ÐµÑ‰ÐµÐ½Ð¸Ð¹: 0 days 00:00:58.675153

# %%
color_status=('work', 'pre_done')
min_date='1W'
tasks = planner.task_repository.get_task_by_color_status(color_status)
task_timings = planner.timing_processor.create_task_timing_structure(tasks)
calendar = planner.calendar_manager.create_calendar_structure(task_timings)

# %%
calendar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 calendar
#
# NameError: name 'calendar' is not defined

# %%
color_status=('wait', 'work', 'pre_done')
tasks = planner.task_repository.get_task_by_color_status(color_status)
task_timings = planner.timing_processor.create_task_timing_structure(tasks)
calendar = planner.task_calendar_manager.create_task_calendar_structure(task_timings)
#planner.task_calendar_manager.write_task_calendar_to_sheet(calendar)

# %%
calendar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 calendar
#
# NameError: name 'calendar' is not defined

# %%
OPENAI_API_KEY = 'sk-REDACTED'
import os
import asyncio
import httpx
from openai import OpenAI
from openai import AsyncOpenAI


#client = OpenAI(api_key=OPENAI_API_KEY)

proxies = {
    "https://": "http://proxy.example:8000",
}

proxies = None

http_client=
client = AsyncOpenAI(
    api_key=OPENAI_API_KEY,
    http_client=httpx.AsyncClient(proxies=proxies)
)

completion = await client.chat.completions.create(
    model="gpt-4-0125-preview",
    messages=[
        {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
        {"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}
    ]
)

print(completion.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[22], line 23
#      17 http_client=httpx.AsyncClient(proxies=proxies)
#      18 client = AsyncOpenAI(
#      19     api_key=OPENAI_API_KEY,
#      20     http_client=http_client
#      21 )
# ---> 23 completion = await client.chat.completions.create(
#      24     model="gpt-4-0125-preview",
#      25     messages=[
#      26         {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
#      27         {"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}
#      28     ]
#      29 )
#      31 print(completion.choices[0].message)
#
# File D:\PROJECTS\python\SCRIPT\TABLE_PARSE\venv\Lib\site-packages\openai\resources\chat\completions.py:1334, in AsyncCompletions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#    1282 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1283 async def create(
#    1284     self,
#    (...)
#    1332     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1333 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
# -> 1334     return await self._post(
#    1335         "/chat/completions",
#    1336         body=await async_maybe_transform(
#    1337             {
#    1338                 "messages": messages,
#    1339                 "model": model,
#    1340                 "frequency_penalty": frequency_penalty,
#    1341                 "function_call": function_call,
#    1342                 "functions": functions,
#    1343                 "logit_bias": logit_bias,
#    1344                 "logprobs": logprobs,
#    1345                 "max_tokens": max_tokens,
#    1346                 "n": n,
#    1347                 "presence_penalty": presence_penalty,
#    1348                 "response_format": response_format,
#    1349                 "seed": seed,
#    1350                 "stop": stop,
#    1351                 "stream": stream,
#    1352                 "temperature": temperature,
#    1353                 "tool_choice": tool_choice,
#    1354                 "tools": tools,
#    1355                 "top_logprobs": top_logprobs,
#    1356                 "top_p": top_p,
#    1357                 "user": user,
#    1358             },
#    1359             completion_create_params.CompletionCreateParams,
#    1360         ),
#    1361         options=make_request_options(
#    1362             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1363         ),
#    1364         cast_to=ChatCompletion,
#    1365         stream=stream or False,
#    1366         stream_cls=AsyncStream[ChatCompletionChunk],
#    1367     )
#
# File D:\PROJECTS\python\SCRIPT\TABLE_PARSE\venv\Lib\site-packages\openai\_base_client.py:1743, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1729 async def post(
#    1730     self,
#    1731     path: str,
#    (...)
#    1738     stream_cls: type[_AsyncStreamT] | None = None,
#    1739 ) -> ResponseT | _AsyncStreamT:
#    1740     opts = FinalRequestOptions.construct(
#    1741         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1742     )
# -> 1743     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File D:\PROJECTS\python\SCRIPT\TABLE_PARSE\venv\Lib\site-packages\openai\_base_client.py:1446, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1437 async def request(
#    1438     self,
#    1439     cast_to: Type[ResponseT],
#    (...)
#    1444     remaining_retries: Optional[int] = None,
#    1445 ) -> ResponseT | _AsyncStreamT:
# -> 1446     return await self._request(
#    1447         cast_to=cast_to,
#    1448         options=options,
#    1449         stream=stream,
#    1450         stream_cls=stream_cls,
#    1451         remaining_retries=remaining_retries,
#    1452     )
#
# File D:\PROJECTS\python\SCRIPT\TABLE_PARSE\venv\Lib\site-packages\openai\_base_client.py:1537, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1534         await err.response.aread()
#    1536     log.debug("Re-raising status error")
# -> 1537     raise self._make_status_error_from_response(err.response) from None
#    1539 return await self._process_response(
#    1540     cast_to=cast_to,
#    1541     options=options,
#    (...)
#    1544     stream_cls=stream_cls,
#    1545 )
#
# PermissionDeniedError: Error code: 403 - {'error': {'message': 'Country, region, or territory not supported', 'type': 'request_forbidden', 'param': None, 'code': 'unsupported_country_region_territory'}}

# %%
completion.choices[0].message.content
# Out:
# 'In the land of logic, where code streams flow,\nLies a concept, recursive, in its mysterious glow.\nA method so clever, it calls upon itself,\nIn a looping embrace, like books on a shelf.\n\nImagine a journey, where the path entwines,\nWhere each step forward, to the past, aligns.\nThis method so peculiar, yet elegantly precise,\nThrough the looking glass, it ventures, once, then twice.\n\n"Recursion," they whisper, a magical spell,\nWhere functions nest in functions, an infinite well.\nIt dives into its essence, with no hesitation,\nEmerging with answers, a true revelation.\n\nConsider the legends, the classic tales told,\nOf Fibonacci\'s sequence, ancient and bold.\nEach number a sum, of the two before,\nRecursion unwraps, its mystical lore.\n\nOr the quest for the factorial, a hero\'s fate,\nWhere n! is n times all before it, on its plate.\nThe function calls itself, with each step it takes,\nTill it reaches the beginning, and the spell breaks.\n\nBut beware the abyss, the recursive descent,\nWithout a base case, your efforts are spent.\nFor without a stop, the cycle goes on,\nInto the void, endlessly drawn.\n\nSo here lies recursion, a loop within,\nA mesmerizing dance, a symphony of spin.\nIn the lines of code, where secrets dwell,\nIt casts its charm, it casts its spell.\n\nSo next time you wander through algorithms vast,\nAnd find yourself in recursion\'s grasp,\nEmbrace its beauty, its structured recursion,\nA concept of programming, a poetic immersion.'

# %%
! pip install httpx
# Out:
# Requirement already satisfied: httpx in d:\projects\python\script\table_parse\venv\lib\site-packages (0.25.0)
# Requirement already satisfied: certifi in d:\projects\python\script\table_parse\venv\lib\site-packages (from httpx) (2023.7.22)
# Requirement already satisfied: httpcore<0.19.0,>=0.18.0 in d:\projects\python\script\table_parse\venv\lib\site-packages (from httpx) (0.18.0)
# Requirement already satisfied: idna in d:\projects\python\script\table_parse\venv\lib\site-packages (from httpx) (3.4)
# Requirement already satisfied: sniffio in d:\projects\python\script\table_parse\venv\lib\site-packages (from httpx) (1.3.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in d:\projects\python\script\table_parse\venv\lib\site-packages (from httpcore<0.19.0,>=0.18.0->httpx) (4.0.0)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\projects\python\script\table_parse\venv\lib\site-packages (from httpcore<0.19.0,>=0.18.0->httpx) (0.14.0)
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Ð—Ð°Ð¼ÐµÐ½Ð¸Ñ‚Ðµ Ð½Ð° Ð´Ð°Ð½Ð½Ñ‹Ðµ Ð²Ð°ÑˆÐµÐ³Ð¾ Ð¿Ñ€Ð¾ÐºÑÐ¸
proxy_url = "http://proxy.example:8000"  # ÐŸÑ€Ð¾ÐºÑÐ¸ Ð±ÐµÐ· Ð°ÑƒÑ‚ÐµÐ½Ñ‚Ð¸Ñ„Ð¸ÐºÐ°Ñ†Ð¸Ð¸
# Ð•ÑÐ»Ð¸ Ð²Ð°Ñˆ Ð¿Ñ€Ð¾ÐºÑÐ¸ Ñ‚Ñ€ÐµÐ±ÑƒÐµÑ‚ Ð°ÑƒÑ‚ÐµÐ½Ñ‚Ð¸Ñ„Ð¸ÐºÐ°Ñ†Ð¸Ð¸:
# proxy_url = "http://user-pass@proxy.example:8000"

proxies = {
    "http://": proxy_url,
    "https://": proxy_url,
}

async def test_proxy():
    async with httpx.AsyncClient(proxies=proxies) as client:
        # Ð”ÐµÐ»Ð°ÐµÐ¼ Ð·Ð°Ð¿Ñ€Ð¾Ñ Ð½Ð° httpbin, ÐºÐ¾Ñ‚Ð¾Ñ€Ñ‹Ð¹ Ð²ÐµÑ€Ð½ÐµÑ‚ Ð½Ð°Ð¼ Ð´Ð°Ð½Ð½Ñ‹Ðµ Ð¾ Ð·Ð°Ð¿Ñ€Ð¾ÑÐµ
        response = await client.get('https://httpbin.org/ip')
        return response

# Ð—Ð°Ð¿ÑƒÑÐºÐ°ÐµÐ¼ Ð°ÑÐ¸Ð½Ñ…Ñ€Ð¾Ð½Ð½ÑƒÑŽ Ñ„ÑƒÐ½ÐºÑ†Ð¸ÑŽ Ð¸ Ð¿ÐµÑ‡Ð°Ñ‚Ð°ÐµÐ¼ Ñ€ÐµÐ·ÑƒÐ»ÑŒÑ‚Ð°Ñ‚
result = await test_proxy()
print(result.text)
# Out:
# {
#   "origin": "195.158.194.74"
# }

# %%
from openai import OpenAI
from openai import AsyncOpenAI
from types import MappingProxyType as MapProxy
import httpx

OPENAI_API_KEY = 'sk-REDACTED'
PROXIES = MapProxy({
    'https://': 'http://proxy.example:8000',
})

def main():
    proxies = dict(PROXIES)

    client = OpenAI(
        api_key=OPENAI,
        http_client=httpx.Client(proxies=proxies)
    )
    model = 'gpt-3.5-turbo'
    messages = 'ÐŸÑ€Ð¸Ð²ÐµÑ‚, ÐšÐ°Ðº Ð´ÐµÐ»Ð°?'
    messages = [{'role': 'user', 'content': messages}]
    #ai = planner.openai_agent.chat(msgs)
    completion = client.chat.completions.create(
            model=model,
            messages=messages
        )
    return completion.choices[0].message.content



def handler(event, context):
    print(f'{event=}')
    print(f'{context=}')

    m = main()
    return {
        'statusCode': 200,
        'body': m,
    }


handler(1,1)
# Out:
# event=1
# context=1
# {'statusCode': 200, 'body': 'ÐŸÑ€Ð¸Ð²ÐµÑ‚! Ð£ Ð¼ÐµÐ½Ñ Ð²ÑÐµ Ð¾Ñ‚Ð»Ð¸Ñ‡Ð½Ð¾, ÑÐ¿Ð°ÑÐ¸Ð±Ð¾. ÐšÐ°Ðº Ñƒ Ñ‚ÐµÐ±Ñ?'}

# %%
<!doctypehtml><html lang="en"><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible"content="IE=edge"><meta name="viewport"content="width=device-width,initial-scale=1"><title>The service is temporarily unavailable</title><style>*{margin:0;padding:0}body,html{height:100vh;width:100vw}body{box-sizing:border-box;display:flex;justify-content:center;align-items:center;font-family:'YS Text';color:rgba(0,0,0,.85)}.h{display:flex}.h_i{margin-right:40px}.h_c{width:400px;display:flex;flex-direction:column;padding-top:50px}.h_t{margin-bottom:16px}p{line-height:16px;font-size:13px;font-weight:400}p:not(:last-child){margin-bottom:16px}h1{font-weight:400;font-size:24px;line-height:28px}a{color:#027bf3;text-decoration:none}a:hover{color:#004080}</style><div class="h"><div class="h_i"><svg xmlns="http://www.w3.org/2000/svg"width="230"height="230"fill="none"><path fill="#FF5958"fill-opacity=".9"fill-rule="evenodd"d="M102.281 42.591c1.715-6.401 8.295-10.2 14.697-8.485l73.41 19.67c6.402 1.715 10.201 8.295 8.485 14.697l-2.329 8.693c-1.715 6.402-8.295 10.2-14.697 8.486 6.402 1.715 10.201 8.295 8.485 14.697l-2.07 7.727c-1.715 6.402-8.295 10.201-14.697 8.485 6.402 1.716 10.201 8.296 8.485 14.697l-2.329 8.694c-1.715 6.401-8.295 10.2-14.697 8.485l-73.41-19.67c-6.402-1.716-10.201-8.296-8.486-14.697l2.33-8.694c1.715-6.401 8.295-10.2 14.697-8.485-6.402-1.715-10.201-8.295-8.486-14.697l2.07-7.727c1.716-6.402 8.296-10.2 14.698-8.486-6.402-1.715-10.2-8.295-8.486-14.697l2.33-8.693Z"clip-rule="evenodd"/><path fill="#fff"fill-opacity=".72"fill-rule="evenodd"d="M128.502 75.625a3.001 3.001 0 0 1 5.197-3l8.399 14.548 14.548-8.399a3 3 0 1 1 3 5.196l-14.548 8.4 8.4 14.548a3 3 0 0 1-5.197 3l-8.399-14.548-14.548 8.399a3 3 0 1 1-3-5.196l14.548-8.4-8.4-14.548Z"clip-rule="evenodd"/><path fill="#262626"fill-rule="evenodd"d="M102.708 111.641a11.005 11.005 0 0 1 5.126 6.68l10.272 38.336a8.274 8.274 0 0 1 1.903-.624l-10.244-38.23a13 13 0 0 0-6.057-7.894L73.126 92.252a13 13 0 0 0-9.865-1.298l-29.972 8.03c-6.935 1.859-11.05 8.987-9.192 15.922l19.67 73.411c1.858 6.935 8.986 11.05 15.921 9.192l45.066-12.075a6.302 6.302 0 0 1 .299-2.151l-45.882 12.294c-5.868 1.573-11.9-1.91-13.472-7.778l-19.67-73.41c-1.573-5.868 1.91-11.9 7.778-13.472l29.972-8.031a11 11 0 0 1 8.347 1.099l30.582 17.656Zm8.962 69.869-.928 2.319 3.038-.814c6.935-1.858 11.051-8.986 9.193-15.921l-1.531-5.713a2.804 2.804 0 0 0-1.841.856l1.44 5.374c1.572 5.868-1.91 11.9-7.778 13.472l-1.593.427Z"clip-rule="evenodd"/><g clip-path="url(#a)"><path fill="#A6BCD2"fill-opacity=".